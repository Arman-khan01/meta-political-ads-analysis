# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


df_clean = pd.read_csv("FINAL_facebook_ads_dataset.csv")

# 1. Select only the continuous numeric columns for correlation
numeric_cols = df_clean[['spend', 'impressions', 'estimated_audience_size']]

# Calculate the correlation matrix
corr_matrix = numeric_cols.corr()

# 2. Plot the Heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(
    corr_matrix, 
    annot=True,          # Prints the exact correlation numbers inside the boxes
    cmap='coolwarm',     # Red for positive correlation, Blue for negative
    vmin=-1, vmax=1,     # Sets the scale from -1 to 1
    linewidths=1,
    square=True
)

# 3. Formatting
plt.title('Conclusion: Statistical Correlation of Campaign Metrics', fontsize=14, fontweight='bold')
# Clean up the labels for the report
plt.xticks(ticks=[0.5, 1.5, 2.5], labels=['Financial Spend', 'Actual Impressions', 'Target Audience'], rotation=0)
plt.yticks(ticks=[0.5, 1.5, 2.5], labels=['Financial Spend', 'Actual Impressions', 'Target Audience'], rotation=0)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 12
#       9 numeric_cols = df_clean[['spend', 'impressions', 'estimated_audience_size']]
#      11 # Calculate the correlation matrix
# ---> 12 corr_matrix = numeric_cols.corr()
#      14 # 2. Plot the Heatmap
#      15 plt.figure(figsize=(8, 6))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:13117, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13115 cols = data.columns
#   13116 idx = cols.copy()
# > 13117 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13119 if method == "pearson":
#   13120     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2079 if dtype is not None:
# ...
